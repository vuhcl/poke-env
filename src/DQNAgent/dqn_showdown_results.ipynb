# %% [markdown]
# # Visualizing DQN RL Agent Results in Pokemon Showdown

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Training Process

# %%
random_train = pd.read_csv('RandomPlayer_trainlog_20000eps.csv')
random_train.drop('Unnamed: 0', axis=1, inplace=True)
random_train_stats = random_train.describe().round(2)
random_train_stats
# Out:
#        episode_reward  nb_episode_steps  nb_steps
# count          584.00            584.00    584.00
# mean            30.90             34.24  11148.61
# std             24.44             14.53   5491.30
# min            -46.84             11.00     39.00
# 25%             35.26             25.00   6753.50
# 50%             38.96             31.00  11571.00
# 75%             41.88             41.00  15852.50
# max             47.87            113.00  19998.00

# %%
plt.figure(figsize=(16,4), dpi=100)
plt.scatter(random_train['nb_steps'], random_train['episode_reward'], alpha = 0.7)
plt.title("DQN Agent Trained Against RandomPlayer", size=15)
plt.xlabel('Number of Steps')
plt.ylabel('Episode Reward')
plt.show()

plt.hist(random_train['episode_reward'], alpha = 0.7)
plt.title(f"Reward Histogram of DQN Agent Trained Against Random Player \n Mean reward: {random_train_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# ## Testing Process

# %%
random_test = pd.read_csv('TrainedRandomPlayer(20000)vsRandomPlayer_testlog_100eps.csv')
random_test.drop('Unnamed: 0', axis=1, inplace=True)
random_stats = random_test.describe().round(2)
random_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean            37.95     27.96
# std             15.31     11.82
# min            -40.40     11.00
# 25%             38.53     21.00
# 50%             41.32     25.00
# 75%             43.67     32.00
# max             47.49     89.00

# %%
max_test = pd.read_csv('TrainedRandomPlayer(20000)vsMaxPlayer_testlog_100eps.csv')
max_test.drop('Unnamed: 0', axis=1, inplace=True)
max_stats = max_test.describe().round(2)
max_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean            19.16     25.99
# std             31.47     10.10
# min            -41.27     12.00
# 25%             16.04     19.00
# 50%             35.24     24.00
# 75%             38.74     29.00
# max             47.00     73.00

# %%
rl_test = pd.read_csv('TrainedRandomPlayer(20000)vsRLPlayer_testlog_100eps.csv')
rl_test.drop('Unnamed: 0', axis=1, inplace=True)
rl_stats = rl_test.describe().round(2)
rl_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean            37.60     25.88
# std             12.89     10.06
# min            -33.00     13.00
# 25%             38.01     19.00
# 50%             38.95     24.00
# 75%             41.78     29.00
# max             47.57     75.00

# %%
plt.figure(figsize=(16,12), dpi=120)

plt.subplot(2,2,1)
plt.hist(random_test['episode_reward'], alpha = 0.7)
plt.title(f"Eval: Reward of Trained DQN Agent vs RandomPlayer \n Mean reward: {random_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')

plt.subplot(2,2,2)
plt.hist(max_test['episode_reward'], alpha = 0.7, color='coral')
plt.title(f"Eval: Reward of Trained DQN Agent vs MaxDamagePlayer \n Mean reward: {max_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')

plt.subplot(2,2,3)
plt.hist(rl_test['episode_reward'], alpha = 0.7, color='orange')
plt.title(f"Eval: Reward of Trained DQN Agent vs FrozenRLPlayer \n Mean reward: {rl_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')

plt.tight_layout()

# %% [markdown]
# # Visualizing DQN RL Agent Results in Pokemon Showdown

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Training Process

# %%
random_train = pd.read_csv('RandomPlayer_trainlog_10000eps.csv')
random_train.drop('Unnamed: 0', axis=1, inplace=True)
random_train_stats = random_train.describe().round(2)
random_train_stats
# Out:
#        episode_reward  nb_episode_steps  nb_steps
# count          167.00            167.00    167.00
# mean             0.70             59.66   5048.10
# std             35.88             21.37   2875.27
# min            -43.51             26.00     83.00
# 25%            -35.02             46.00   2679.00
# 50%             32.03             56.00   5028.00
# 75%             34.60             66.00   7486.00
# max             46.04            150.00   9963.00

# %%
plt.figure(figsize=(16,4), dpi=100)
plt.scatter(random_train['nb_steps'], random_train['episode_reward'], alpha = 0.7)
plt.title("CEM Agent Trained Against RandomPlayer", size=15)
plt.xlabel('Number of Steps')
plt.ylabel('Episode Reward')
plt.show()

plt.hist(random_train['episode_reward'], alpha = 0.7)
plt.title(f"Reward Histogram of CEM Agent Trained Against Random Player \n Mean reward: {random_train_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# ## Testing Process

# %%
random_test = pd.read_csv('(RandomPlayer_10000)RandomPlayer_testlog_100eps.csv')
random_test.drop('Unnamed: 0', axis=1, inplace=True)
random_stats = random_test.describe().round(2)
random_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean             2.10     51.80
# std             36.63     22.46
# min            -42.85     14.00
# 25%            -33.36     38.00
# 50%             32.18     47.50
# 75%             37.35     61.25
# max             47.68    153.00

# %%
max_test = pd.read_csv('(RandomPlayer_10000)MaxPlayer_testlog_100eps.csv')
max_test.drop('Unnamed: 0', axis=1, inplace=True)
max_stats = max_test.describe().round(2)
max_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean           -26.91     37.93
# std             27.68     20.27
# min            -48.00     15.00
# 25%            -41.26     26.00
# 50%            -38.30     35.00
# 75%            -35.29     42.25
# max             40.87    155.00

# %%
plt.figure(figsize=(16,4), dpi=100)

plt.subplot(1,2,1)
plt.hist(random_test['episode_reward'], alpha = 0.7)
plt.title(f"Eval: Reward of Trained CEM Agent vs RandomPlayer \n Mean reward: {random_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')

plt.subplot(1,2,2)
plt.hist(max_test['episode_reward'], alpha = 0.7, color='coral')
plt.title(f"Eval: Reward of Trained CEM Agent vs MaxDamagePlayer \n Mean reward: {max_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

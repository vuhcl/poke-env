# %% [markdown]
# # Visualizing SARSA RL Agent Results in Pokemon Showdown

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Trained Against Random Player

# %% [markdown]
# ### Training Process

# %%
random_train = pd.read_csv('RandomPlayer_trainlog_20000eps.csv')
random_train.drop('Unnamed: 0', axis=1, inplace=True)
random_train_stats = random_train.describe().round(2)
random_train_stats
# Out:
#        episode_reward  nb_episode_steps  nb_steps
# count          396.00            396.00    396.00
# mean            14.64             50.50  10904.16
# std             34.29             22.48   5817.93
# min            -43.60             13.00    112.00
# 25%            -32.49             34.00   5995.75
# 50%             34.99             47.00  11515.00
# 75%             38.84             60.25  16179.00
# max             47.11            154.00  19999.00

# %%
plt.figure(figsize=(16,4), dpi=100)
plt.scatter(random_train['nb_steps'], random_train['episode_reward'], alpha = 0.7)
plt.title("SARSA Agent Trained Against RandomPlayer", size=15)
plt.xlabel('Number of Steps')
plt.ylabel('Episode Reward')
plt.show()

plt.hist(random_train['episode_reward'], alpha = 0.7)
plt.title(f"Reward Histogram of SARSA Agent Trained Against Random Player \n Mean reward: {random_train_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Testing Process

# %%
random_test = pd.read_csv('(RandomPlayer_20000)RandomPlayer_testlog_100eps.csv')
random_test.drop('Unnamed: 0', axis=1, inplace=True)
random_stats = random_test.describe().round(2)
random_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean            27.78     37.80
# std             27.81     19.72
# min            -40.77     14.00
# 25%             35.07     25.75
# 50%             38.60     34.50
# 75%             41.62     44.25
# max             48.00    135.00

# %%
max_test = pd.read_csv('(RandomPlayer_20000)MaxPlayer_testlog_100eps.csv')
max_test.drop('Unnamed: 0', axis=1, inplace=True)
max_stats = max_test.describe().round(2)
max_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean            -7.33     33.67
# std             35.78     19.11
# min            -47.95     17.00
# 25%            -35.92     24.00
# 50%            -32.97     29.00
# 75%             34.69     35.25
# max             41.72    137.00

# %%
plt.figure(figsize=(16,4), dpi=100)

plt.subplot(1,2,1)
plt.hist(random_test['episode_reward'], alpha = 0.7)
plt.title(f"Eval: Reward of Trained SARSA Agent vs RandomPlayer \n Mean reward: {random_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')

plt.subplot(1,2,2)
plt.hist(max_test['episode_reward'], alpha = 0.7, color='coral')
plt.title(f"Eval: Reward of Trained SARSA Agent vs MaxDamagePlayer \n Mean reward: {max_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Trained Against Max Damage Player

# %%
random_train = pd.read_csv('MaxDamagePlayer_trainlog_20000eps.csv')
random_train.drop('Unnamed: 0', axis=1, inplace=True)
random_train_stats = random_train.describe().round(2)
random_train_stats
# Out:
#        episode_reward  nb_episode_steps  nb_steps
# count          547.00            547.00     547.0
# mean           -29.85             36.55    9746.9
# std             24.51             15.86    5821.1
# min            -48.00             12.00      28.0
# 25%            -41.52             27.00    4727.0
# 50%            -38.43             33.00    9671.0
# 75%            -35.23             42.00   14761.0
# max             41.35            138.00   19993.0

# %%
plt.figure(figsize=(16,4), dpi=100)
plt.scatter(random_train['nb_steps'], random_train['episode_reward'], alpha = 0.7)
plt.title("SARSA Agent Trained Against MaxDamagePlayer", size=15)
plt.xlabel('Number of Steps')
plt.ylabel('Episode Reward')
plt.show()

plt.hist(random_train['episode_reward'], alpha = 0.7)
plt.title(f"Reward Histogram of SARSA Agent Trained Against MaxDamagePlayer \n Mean reward: {random_train_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Testing Process

# %%
random_test = pd.read_csv('(MaxDamagePlayer_20000)RandomPlayer_testlog_100eps.csv')
random_test.drop('Unnamed: 0', axis=1, inplace=True)
random_stats = random_test.describe().round(2)
random_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean            27.62     42.41
# std             27.17     22.22
# min            -37.18     15.00
# 25%             32.82     26.75
# 50%             38.27     36.00
# 75%             41.55     52.75
# max             47.77    125.00

# %%
max_test = pd.read_csv('(MaxDamagePlayer_20000)MaxPlayer_testlog_100eps.csv')
max_test.drop('Unnamed: 0', axis=1, inplace=True)
max_stats = max_test.describe().round(2)
max_stats
# Out:
#        episode_reward  nb_steps
# count          100.00    100.00
# mean            -9.11     34.96
# std             35.04     13.37
# min            -44.58     14.00
# 25%            -36.00     25.75
# 50%            -32.73     31.00
# 75%             33.00     41.50
# max             44.06     78.00

# %%
plt.figure(figsize=(16,4), dpi=100)

plt.subplot(1,2,1)
plt.hist(random_test['episode_reward'], alpha = 0.7)
plt.title(f"Eval: Reward of Trained SARSA Agent vs RandomPlayer \n Mean reward: {random_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')

plt.subplot(1,2,2)
plt.hist(max_test['episode_reward'], alpha = 0.7, color='coral')
plt.title(f"Eval: Reward of Trained SARSA Agent vs MaxDamagePlayer \n Mean reward: {max_stats['episode_reward']['mean']}", size=15)
plt.xlabel('Episode Reward')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
